# %%
import read
import process
import numpy as np
data, label = read.readData()
data = process.normalization(data)
from keras.models import Sequential
from keras.layers import Dense, Activation
import keras

model = Sequential([
    Dense(32, input_shape=(27,)),
    Activation('relu'),
    Dense(10),
    Activation('softmax'),
])
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
label = keras.utils.to_categorical(label, num_classes=10)
model.fit(data, label, epochs=200,validation_split=0.33, batch_size=10)
# Out:
# D:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# Train on 401 samples, validate on 199 samples
# Epoch 1/200
# 401/401 [==============================] - 0s 683us/step - loss: 2.1844 - acc: 0.4863 - val_loss: 2.4162 - val_acc: 0.0000e+00
# Epoch 2/200
# 401/401 [==============================] - 0s 126us/step - loss: 1.9139 - acc: 0.6484 - val_loss: 2.5506 - val_acc: 0.0000e+00
# Epoch 3/200
# 401/401 [==============================] - 0s 139us/step - loss: 1.6393 - acc: 0.6633 - val_loss: 2.7476 - val_acc: 0.0000e+00
# Epoch 4/200
# 401/401 [==============================] - 0s 142us/step - loss: 1.3890 - acc: 0.6608 - val_loss: 2.9977 - val_acc: 0.0000e+00
# Epoch 5/200
# ...

# %%
import read3

# %%
import importlib

# %%
importlib.reload(read3)
# Out:
# <module 'read3' from 'C:\\Users\\Jay\\Desktop\\capstone\\read3.py'>

# %%
train_data, train_label, test_data, test_label = read3.readData()

# %%
model = Sequential([
    Dense(32, input_shape=(27,)),
    Activation('relu'),
    Dense(10),
    Activation('softmax'),
])
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(train_data, train_label, epochs=200, validation_data=(test_data, test_label), batch_size=10)
# Out:
# Train on 397 samples, validate on 193 samples
# Epoch 1/200
# 397/397 [==============================] - 0s 541us/step - loss: 3.8771 - acc: 0.3199 - val_loss: 3.1950 - val_acc: 0.4093
# Epoch 2/200
# 397/397 [==============================] - 0s 126us/step - loss: 3.1908 - acc: 0.4005 - val_loss: 2.7381 - val_acc: 0.5285
# Epoch 3/200
# 397/397 [==============================] - 0s 124us/step - loss: 2.7694 - acc: 0.5189 - val_loss: 2.3782 - val_acc: 0.5803
# Epoch 4/200
# 397/397 [==============================] - 0s 117us/step - loss: 2.4904 - acc: 0.5642 - val_loss: 1.7215 - val_acc: 0.6218
# Epoch 5/200
# 397/397 [==============================] - 0s 126us/step - loss: 1.7832 - acc: 0.6045 - val_loss: 1.4482 - val_acc: 0.6684
# Epoch 6/200
# 397/397 [==============================] - 0s 134us/step - loss: 1.5391 - acc: 0.6599 - val_loss: 1.3089 - val_acc: 0.6891
# Epoch 7/200
# ...

# %%
model = Sequential([
    Dense(32, input_shape=(27,)),
    Activation('relu'),
    Dense(10),
    Activation('softmax'),
])
model.compile(optimizer='rmsprop',
              loss='categorical_crossentropy',
              metrics=['accuracy'])
